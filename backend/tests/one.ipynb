# %%
import imaplib
import email

# %%
mail = imaplib.IMAP4_SSL('imap.gmail.com')
mail.login("apexconnect40@gmail.com", "ndch royt nrdy iara")
# Out:
# ('OK', [b'apexconnect40@gmail.com authenticated (Success)'])

# %%
mail.select("inbox")
status, messages = mail.search(None, 'ALL')

# %%
print(messages)
for num in messages[0].split():
    status, data = mail.fetch(num, '(RFC822)')
    msg = email.message_from_bytes(data[0][1])
    print("Subject:", msg["subject"])
    print("From:", msg["from"])
    print("To:", msg["to"])
    print("Date:", msg["date"])
    if msg.get_payload(decode=True):
        print("Body:", msg.get_payload(decode=True).decode('utf-8'))

    print("-" * 50)
# Out:
# [b'1 2 3 4 5 6']
# Subject: Re: yo
# From: Sai Varun Chowdary Poludasu <saivarunchowdarypoludasu4248@gmail.com>
# To: apexconnect 1 <apexconnect40@gmail.com>
# Date: Fri, 27 Feb 2026 19:11:45 +0530
# --------------------------------------------------
# Subject: Security alert
# From: Google <no-reply@accounts.google.com>
# To: apexconnect40@gmail.com
# Date: Fri, 27 Feb 2026 13:45:47 GMT
# --------------------------------------------------
# Subject: Security alert
# From: Google <no-reply@accounts.google.com>
# To: apexconnect40@gmail.com
# Date: Fri, 27 Feb 2026 13:46:22 GMT
# --------------------------------------------------
# Subject: Security alert
# From: Google <no-reply@accounts.google.com>
# To: apexconnect40@gmail.com
# Date: Fri, 27 Feb 2026 13:47:35 GMT
# --------------------------------------------------
# Subject: 2-Step Verification turned on
# From: Google <no-reply@accounts.google.com>
# To: apexconnect40@gmail.com
# Date: Fri, 27 Feb 2026 13:47:46 GMT
# --------------------------------------------------
# Subject: Security alert
# From: Google <no-reply@accounts.google.com>
# To: apexconnect40@gmail.com
# Date: Fri, 27 Feb 2026 13:50:03 GMT
# --------------------------------------------------
